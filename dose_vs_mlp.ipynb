# %% [markdown]
# # Dose-vs-MLP Comparison (NanoTox)
#
# Runs the dose-threshold vs MLP comparison under LOMO on the NanoTox benchmark
# (dose CI, MLP CI, CI-overlap, McNemar). **Just run the cell below** — it imports the
# analysis script from `scripts/` and runs it against the NanoTox dataset resolved via `common.py`.

# %%
# ============================================================
# DOSE-vs-MLP COMPARISON (NanoTox) - run in one cell
# dose-threshold baseline vs MLP under LOMO: CI, CI-overlap, McNemar
# ============================================================
import os, sys, importlib

SCRIPTS = os.path.join(os.getcwd(), "scripts")   # notebook lives at the repo root
os.chdir(SCRIPTS); sys.path.insert(0, SCRIPTS)
print("cwd:", os.getcwd())

import common
print("NanoTox resolved to:", common.DATA_PATH, "| exists:", os.path.exists(str(common.DATA_PATH)))

import dose_vs_mlp_comparison
importlib.reload(dose_vs_mlp_comparison)
dose_vs_mlp_comparison.main()   # NanoTox-only
