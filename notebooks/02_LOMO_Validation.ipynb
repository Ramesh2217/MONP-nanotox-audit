# %% [markdown]
# # Leave-One-Oxide-Out Validation
#
# Evaluate the five classifiers and the dose-threshold baseline under random k-fold and LOMO validation.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../scripts'))
import common

# %% [markdown]
# Classifier results (k-fold vs LOMO).

# %%
import lomo_validation
lomo_validation.main()

# %% [markdown]
# Dose-threshold baseline under LOMO.

# %%
import baseline_models
baseline_models.main()

# %% [markdown]
# Leakage gap vs duplication fraction.

# %%
import leakage_curve
leakage_curve.main()
