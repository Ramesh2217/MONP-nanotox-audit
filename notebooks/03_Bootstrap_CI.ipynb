# %% [markdown]
# # Bootstrap Confidence Intervals
#
# Estimate 95% bootstrap confidence intervals for the LOMO MCC of each model and the baseline.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../scripts'))
import common

# %% [markdown]
# Run bootstrap CIs (1,000 resamples).

# %%
import bootstrap_ci
bootstrap_ci.main()
