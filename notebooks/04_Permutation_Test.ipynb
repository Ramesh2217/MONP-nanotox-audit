# %% [markdown]
# # Permutation Test
#
# Test whether the observed LOMO performance differs from a label-shuffled null.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../scripts'))
import common

# %% [markdown]
# Run the permutation test (1,000 permutations).

# %%
import permutation_test
permutation_test.main()
