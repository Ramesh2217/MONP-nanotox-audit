# %% [markdown]
# # Seed Stability
#
# Assess stability of LOMO results across eight random seeds {0, 1, 2, 3, 7, 13, 42, 99}.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../scripts'))
import common

# %% [markdown]
# Run the seed-stability assessment.

# %%
import seed_stability
seed_stability.main()
