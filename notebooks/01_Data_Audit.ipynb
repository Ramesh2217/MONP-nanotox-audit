# %% [markdown]
# # Data Audit
#
# Audit and remove exact duplicate records, reproducing the 483 → 364 (68 cytotoxic) deduplication reported in Section 2.1.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../scripts'))
import common

# %% [markdown]
# Run the duplicate audit.

# %%
import duplicate_audit
duplicate_audit.main()

# %% [markdown]
# Inspect per-oxide composition.

# %%
import pandas as pd
pd.read_csv('../results/per_oxide_composition.csv')
